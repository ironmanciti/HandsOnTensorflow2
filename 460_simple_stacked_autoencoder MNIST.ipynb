# %% [markdown]
# # Simple and Stacked Autoencoder with MNIST - Dense
#
# - fashion_mnist dataset 을 이용한 deep autoencoder 생성
#
#
# - Mnist dataset 의 손글씨체를 encoding 후 decoding 하여 복원

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense
import matplotlib.pyplot as plt

# %%
(X_train, _), (X_test, _) = fashion_mnist.load_data()
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# sample image 시각화

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 4))

for i in range(10):
    ax[i].imshow(X_test[i], cmap='gray')
    ax[i].set_xticks([])
    ax[i].set_yticks([])

# %% [markdown]
# - data normalization
# - 2차원 image 를 1 차원으로 변경

# %%
X_train = X_train / 255.           
X_test = X_test / 255.

X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)
X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %% [markdown]
# # stacked autoencoder 작성

# %%
input = Input(shape=(784,))

# stacked autoencoder
x = Dense(units=128, activation='relu')(input)
x = Dense(units=64, activation='relu')(x)
encoder = Dense(units=32, activation='relu')(x)

x = Dense(units=64, activation='relu')(encoder)
x = Dense(units=128, activation='relu')(x)
decoder = Dense(units=784, activation='sigmoid')(x)

# autoencoder model
encoder_model = Model(inputs=input, outputs=encoder)
autoencoder = Model(inputs=input, outputs=decoder)
autoencoder.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# - model summary 및 시각화

# %%
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 784)               101136
#
# =================================================================
# Total params: 222384 (868.69 KB)
# Trainable params: 222384 (868.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = autoencoder.fit(X_train, X_train, epochs=50, shuffle=True, 
              batch_size=256, validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 5ms/step - loss: 0.3909 - val_loss: 0.3224
# Epoch 2/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3127 - val_loss: 0.3089
# Epoch 3/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3034 - val_loss: 0.3022
# Epoch 4/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2982 - val_loss: 0.2980
# Epoch 5/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2948 - val_loss: 0.2954
# Epoch 6/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2924 - val_loss: 0.2934
# Epoch 7/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2906 - val_loss: 0.2916
# Epoch 8/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2889 - val_loss: 0.2901
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2875 - val_loss: 0.2889
# Epoch 10/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2865 - val_loss: 0.2880
# Epoch 11/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2855 - val_loss: 0.2874
# Epoch 12/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2846 - val_loss: 0.2865
# Epoch 13/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2838 - val_loss: 0.2858
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2832 - val_loss: 0.2850
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2825 - val_loss: 0.2845
# Epoch 16/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2819 - val_loss: 0.2842
# Epoch 17/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2813 - val_loss: 0.2835
# Epoch 18/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2808 - val_loss: 0.2829
# Epoch 19/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2804 - val_loss: 0.2823
# Epoch 20/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2799 - val_loss: 0.2819
# Epoch 21/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2795 - val_loss: 0.2816
# Epoch 22/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2791 - val_loss: 0.2814
# Epoch 23/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2789 - val_loss: 0.2809
# Epoch 24/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2784 - val_loss: 0.2806
# Epoch 25/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2782 - val_loss: 0.2805
# Epoch 26/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2778 - val_loss: 0.2800
# Epoch 27/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2775 - val_loss: 0.2796
# Epoch 28/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2773 - val_loss: 0.2799
# Epoch 29/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2770 - val_loss: 0.2795
# Epoch 30/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2768 - val_loss: 0.2792
# Epoch 31/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2766 - val_loss: 0.2789
# Epoch 32/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2764 - val_loss: 0.2790
# Epoch 33/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2762 - val_loss: 0.2784
# Epoch 34/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2761 - val_loss: 0.2786
# Epoch 35/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2758 - val_loss: 0.2782
# Epoch 36/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2757 - val_loss: 0.2780
# Epoch 37/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2755 - val_loss: 0.2779
# Epoch 38/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2754 - val_loss: 0.2778
# Epoch 39/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2752 - val_loss: 0.2776
# Epoch 40/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2751 - val_loss: 0.2774
# Epoch 41/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2750 - val_loss: 0.2773
# Epoch 42/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2748 - val_loss: 0.2773
# Epoch 43/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2747 - val_loss: 0.2771
# Epoch 44/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2746 - val_loss: 0.2769
# Epoch 45/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2745 - val_loss: 0.2775
# Epoch 46/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2744 - val_loss: 0.2767
# Epoch 47/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2743 - val_loss: 0.2768
# Epoch 48/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2742 - val_loss: 0.2766
# Epoch 49/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2741 - val_loss: 0.2765
# Epoch 50/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2740 - val_loss: 0.2765

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation_loss')
plt.legend()

# %%
fig, ax = plt.subplots(3, 10, figsize=(20, 8))

for i in range(10):
    ax[0, i].imshow(X_test[i].reshape(28, 28), cmap='gray')
    
    img = np.expand_dims(X_test[i], axis=0)
    
    ax[1, i].imshow(encoder_model.predict(img, 
                              verbose=0).reshape(8, 4), cmap='gray')
    ax[2, i].imshow(autoencoder.predict(img, 
                            verbose=0).reshape(28, 28), cmap='gray')
    
    ax[0, i].axis('off')
    ax[1, i].axis('off')
    ax[2, i].axis('off')
